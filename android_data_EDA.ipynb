# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style = 'darkgrid',font_scale=1.5)

import warnings as ws
ws.filterwarnings('ignore')

# %%
# Displaying all the columns
pd.pandas.set_option('display.max_columns',None)

# %%
# Reading the file
df = pd.read_csv('mobiles_for_eda.csv')
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#     brand    ram_gb  storage_gb      expandable_storage      battery_type  \
# 0   Redmi  4 GB RAM   64 GB ROM  Expandable Upto 512 GB  standard battery
# 1  Realme  4 GB RAM   64 GB ROM                     NaN  standard battery
# 2  Realme  4 GB RAM  128 GB ROM                     NaN  standard battery
# 3  Realme  4 GB RAM  128 GB ROM                     NaN  standard battery
# 4  Realme  3 GB RAM   32 GB ROM  Expandable Upto 256 GB  standard battery
#
#    battery_mah  rear_camera_mp  front_camera_mp  rear_camera_count  rating  \
# 0       5000.0              14              8.0                  2     4.4
# 1       5000.0              24              8.0                  4     4.5
# 2       5000.0              24              8.0                  4     4.5
# 3       5000.0              24              8.0                  4     4.5
# 4       4000.0              15              5.0                  2     4.4
#
#    reviews  price  display_inch processor_family  warranty_months
# ...

# %%
df.columns
# Out:
# Index(['brand', 'ram_gb', 'storage_gb', 'expandable_storage', 'battery_type',
#        'battery_mah', 'rear_camera_mp', 'front_camera_mp', 'rear_camera_count',
#        'rating', 'reviews', 'price', 'display_inch', 'processor_family',
#        'warranty_months'],
#       dtype='object')

# %% [markdown]
# ### Total price contribution by brand

# %%
brand_price = df.groupby('brand')['price'].sum()

# top10 brands
top_10_brands = brand_price.sort_values(ascending=False).head(10)

# Plotting pie chart
plt.figure(figsize = (9,9))
top_10_brands.plot.pie(autopct='%1.1f%%',startangle=90,pctdistance=0.8,labeldistance=1.1)
plt.title('Brand_wise contribution to total price')
plt.ylabel('')
plt.show()

# %% [raw]
# Observation
# Samsung dominates the market with ~30% of the total price contribution, making it the single largest contributor.
#
# Realme (~17%) and Redmi (~13%) follow, indicating strong presence in the high-volume, mid-range segment.
#
# OPPO (~12%) and Vivo (~11%) together account for a substantial share, highlighting their competitive positioning across multiple price tiers.

# %%
def top_10_price_contr(feature):
    data = (
        df.groupby(feature)['price'].sum()
        .sort_values(ascending=False)
        .head(10)
    )

    plt.figure(figsize=(10,6))
    data.plot(
        kind='bar',
        color = plt.cm.tab10(range(len(data)))
    )

    plt.title(f'Top 10 {feature} by Total Price Contribution')
    plt.xlabel(feature)
    plt.ylabel('Total_Price')
    plt.xticks(rotation=45,ha='right')
    plt.tight_layout()
    plt.show()

# %%
top_10_price_contr('display_inch')

# %% [raw]
# Observation
# -->Displays around 6.4–6.7 inches with Full HD+ resolution contribute the highest total price value.
# -->This indicates that mid-to-large screen sizes dominate the market, both in terms of availability and consumer demand.
# -->Smaller or less common display sizes contribute comparatively less, showing limited market adoption.

# %%
top_10_price_contr('processor_family')

# %% [raw]
# Observation
# Snapdragon processors dominate total price contribution, reflecting their widespread adoption across multiple price segments, while MediaTek and Exynos follow with strong presence in mid-range and premium categories

# %%
top_10_price_contr('storage_gb')

# %% [raw]
# Observation
# -->128 GB ROM is the largest contributor to total price, followed by 64 GB and 256 GB.
# -->Extremely low storage variants (≤16 GB) contribute minimally, indicating declining relevance.
# -->Very high storage options exist but have lower contribution due to limited volume.

# %%
top_10_price_contr('expandable_storage')

# %% [raw]
# Observation
# -->Devices supporting expandable storage up to 256 GB or 512 GB contribute the most to total price.
# -->Extremely high expandable limits (1–2 TB) exist but contribute less due to lower adoption.
# -->Very small expandable limits are largely insignificant.

# %%
top_10_price_contr('ram_gb')

# %% [raw]
# Observation
# -->8 GB RAM leads total price contribution, followed by 6 GB and 4 GB RAM.
# -->Lower RAM variants (≤2 GB) contribute minimally, reflecting their presence in entry-level devices.
# -->Very high RAM options exist but contribute less due to niche adoption.

# %%
top_10_price_contr('battery_type')

# %% [raw]
# Observation
# -->Standard battery dominates total price contribution, largely due to inconsistent or generic labeling.
# -->Lithium-ion and lithium-polymer batteries follow, contributing significantly but less than the generic category.

# %%
features_with_nan = [feature for feature in df.columns if df[feature].isna().sum() > 0]
for feature in features_with_nan:
    print(f'{feature} : {df[feature].isna().sum()}')
print('-----------------------------------------------------------------------')
for feature in features_with_nan:
    print(f'{feature} : {round(df[feature].isna().mean(),4)}% missing values')
# Out:
# expandable_storage : 249
# front_camera_mp : 92
# rating : 13
# reviews : 13
# processor_family : 149
# warranty_months : 209
# -----------------------------------------------------------------------
# expandable_storage : 0.253% missing values
# front_camera_mp : 0.0935% missing values
# rating : 0.0132% missing values
# reviews : 0.0132% missing values
# processor_family : 0.1514% missing values
# warranty_months : 0.2124% missing values

# %%
# We need to find the relationship b/w missing values and dependent variable
for feature in features_with_nan:
    data = df.copy()

    data[feature] = np.where(data[feature].isna(),1,0)

    data.groupby(feature)['price'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [raw]
# Observation
# Processor
# Missing processor family is associated with higher-priced phones.
# Premium phones often use custom or less standardized chip naming
#
# Expandable Storage
# Phones where expandable storage information is missing tend to be more expensive.
# High-end phones often don’t support expandable storage
#
# Front Camera MP
# Phones missing front camera information are generally budget devices.
# Cheaper phones often have poorly documented specs
# Missingness correlates with lower price
#
# Ratings
# Expensive phones tend to have missing ratings, likely because they are newly launched or low-volume models.
# Ratings depend on user volume
# New premium phones → fewer reviews → missing ratings
#
# Reviews
# Devices with missing review counts show a higher median price compared to devices with available review data.
# This likely indicates:
# Premium or newly launched devices that haven’t accumulated reviews yet
# High-priced phones where review aggregation may lag
#
# Warranty
# Missing warranty details are more common in costly phones, possibly due to complex or region-specific warranty terms.
# Budget phones have standardized warranty
# Hence, missing indicators should be retained during feature engineering.

# %% [markdown]
# # Numerical Features

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype in ['int64','float64']]
print(f'No_of_numerical_features : {len(numerical_features)}')
# Out:
# No_of_numerical_features : 9

# %%
numerical_features
# Out:
# ['battery_mah',
#  'rear_camera_mp',
#  'front_camera_mp',
#  'rear_camera_count',
#  'rating',
#  'reviews',
#  'price',
#  'display_inch',
#  'warranty_months']

# %% [markdown]
# ## Numerical_Features(Discrete)

# %%
discrete_var = [feature for feature in numerical_features if len(df[feature].unique()) < 25]
print(f'No_of_discrete_var : {len(discrete_var)}')
# Out:
# No_of_discrete_var : 4

# %%
# Finding the relation b/w discrete vars and the dependent variable(Price)
for feature in discrete_var:
    data = df.copy()
    data.groupby(feature)['price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.title(feature)
    plt.show()

# %% [raw]
# Observation
# Rear Camera Count vs Price
# The median price shows a clear upward trend as the number of rear cameras increases.
# Phones with single rear cameras are the lowest priced
# Devices with dual and triple camera setups show a substantial price increase
# Quad-camera phones have the highest median prices
#
# ➡️ This indicates that camera configuration complexity is strongly associated with
#     higher device pricing, making rear camera count a meaningful price driver.
#
# Rating vs Price
# The median price increases consistently with higher ratings.
# Low-rated devices (below ~3.5) are predominantly budget phones
# Prices rise steadily from 4.0 to 4.5 ratings
# A sharp price spike is observed for ratings above 4.5, indicating premium devices
#
# Front_camera_mp vs Price
# 0–5 MP front cameras → low median prices
# → Entry-level / budget phones
#
# 8–16 MP → noticeable price jump
# → Mid-range segment
#
# 32–48 MP → very high median prices
# → Premium phones (flagships, selfie-focused models)
# Higher front camera resolution is treated as a premium feature, especially beyond 16 MP.
# Some MP values (like 40 MP) may have few phones, so spikes can be due to low sample size, not pure causation.
#
# Warranty Months vs Price
# Standard warranty (12 months) is strongly associated with mid to high-priced phones
# Extended warranty (18–36 months) often appears in:
#    --> Budget phones
#    --> Promotional offers
#    --> Brand strategies (not hardware quality)
# Warranty duration shows a non-linear relationship with price, indicating it is not a primary pricing driver compared to hardware features.

# %% [markdown]
# ## Continous Features

# %%
cont_var = [feature for feature in numerical_features if feature not in discrete_var]
print(f'No_of_cont_var : {len(cont_var)}')
# Out:
# No_of_cont_var : 5

# %%
# Finding the dist of cont_values using histogram
for feature in cont_var:
    data = df.copy()
    data[feature].hist(bins = 25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %% [raw]
# Observation
# Most continuous features such as battery capacity and display size show strong standardization, while rear camera megapixels and reviews exhibit high skewness and segmentation. This indicates that pricing is driven more by feature tiers and popularity rather than linear increases in specifications

# %% [markdown]
# ### Applying Log Transformations on cont features

# %%
for feature in cont_var:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data['price'] = np.log(data['price'])
        plt.scatter(data[feature],data['price'])
        plt.xlabel(feature)
        plt.ylabel('price')
        plt.title(feature)
        plt.show()
# Applying log transformations on 0 creates (-inf) values and it breaks the model

# %% [raw]
# Observation
# Reviews
# The reviews feature is zero-inflated and highly right-skewed, indicating many listings with no user engagement.
# Zero values were treated as meaningful rather than missing.
#
# Battery_mah
# Battery capacity shows a strong positive relationship with price. Devices with larger batteries generally fall into higher price ranges, indicating battery capacity is a key contributor to pricing
#
# Rear Camera
# Rear camera resolution has a strong positive association with price. Higher megapixel configurations are consistently linked to premium pricing, though overlap suggests additional features also influence cost.
#
# Display Size
# Display size shows a strong positive correlation with price, with larger screen devices consistently positioned in higher price segments.

# %% [raw]
# Log Transformation reduces skewness and stabilizes the variancebut doesnt guarantee linear relation

# %% [markdown]
# ## Outliers

# %%
for feature in cont_var:
    data = df.copy()
    if 0 in df[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [raw]
# Observation
# Reviews
# The reviews column is naturally capable of having outliers because it represents product popularity.
#
# Battery_mah
# Extremely small batteries are rare and likely belong to older or entry-level models.
# Outliers on the lower side are valid observations, not data errors.
# Battery size is a stable feature, contributing moderately to price but not highly variable
#
# Rear Camera
# Rear camera MP shows controlled variability, suitable for log transformation and modeling.
#
# Display Size
# Display size shows low variance but strong association with modern devices
# Display size is a highly standardized feature, useful but not a major differentiator.

# %% [markdown]
# # Categorical Features

# %%
cat_var = [feature for feature in df.columns if df[feature].dtypes == 'O']
print(f'No of categorical features : {len(cat_var)}')
# Out:
# No of categorical features : 6

# %%
df[cat_var].head()
# Out:
#     brand    ram_gb  storage_gb      expandable_storage      battery_type  \
# 0   Redmi  4 GB RAM   64 GB ROM  Expandable Upto 512 GB  standard battery
# 1  Realme  4 GB RAM   64 GB ROM                     NaN  standard battery
# 2  Realme  4 GB RAM  128 GB ROM                     NaN  standard battery
# 3  Realme  4 GB RAM  128 GB ROM                     NaN  standard battery
# 4  Realme  3 GB RAM   32 GB ROM  Expandable Upto 256 GB  standard battery
#
#   processor_family
# 0       Snapdragon
# 1       Snapdragon
# 2       Snapdragon
# 3       Snapdragon
# 4         Mediatek

# %%
for feature in cat_var:
    print(f'The feature is {feature} and no of categories are {len(df[feature].unique())}')
# Out:
# The feature is brand and no of categories are 54
# The feature is ram_gb and no of categories are 12
# The feature is storage_gb and no of categories are 10
# The feature is expandable_storage and no of categories are 12
# The feature is battery_type and no of categories are 15
# The feature is processor_family and no of categories are 9

# %%
# Finding the relation b/w categorical features and dependent var(price)
for feature in cat_var:
    plt.figure(figsize=(10,6))
    data = df.copy()
    data.groupby(feature)['price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.title(feature)
    plt.show()

# %% [raw]
# Observation
# ram_gb
# Median price increases strongly with RAM size.
# Clear step-wise jump from:
# 1–2 GB RAM → low-budget segment
# 4–6 GB RAM → mid-range
# 8–12 GB RAM → premium segment
#
# 10 GB & 12 GB RAM devices have very high median prices, indicating flagship phones
# RAM is a strong price-driving feature and shows a monotonic relationship with price.
#
# storage_gb
# Higher storage → higher median price.
# Internal storage capacity has a positive but non-linear impact on price.
#
# expandable storage
# High price here does not mean expandable storage causes high price.
# It is confounded with premium phones.
#
# battery type
# Phones with Lithium ion/yes batteries have higher median prices.
#
# Processor family
# Exynos & Snapdragon dominate higher price segments.
# Kirin sits in upper-mid range.
# Mediatek, Unisoc, Spreadtrum → budget phones.

# %% [markdown]
# # Handling the missing values

# %% [markdown]
# ### Categorical features (missing values)

# %%
cat_var_nan = [feature for feature in df.columns if df[feature].isna().sum() > 0 and df[feature].dtypes == 'O']

for feature in cat_var_nan:
    print(f'{feature} : {round(df[feature].isna().mean(),4)}% missing values')
# Out:
# expandable_storage : 0.253% missing values
# processor_family : 0.1514% missing values

# %%
# Replacing the missing values with new label
def replace_cat_nan(df,cat_var_nan):
    data = df.copy()
    data[cat_var_nan] = data[cat_var_nan].fillna('Missing')
    return data

df = replace_cat_nan(df,cat_var_nan)

df[cat_var_nan].isna().sum()
# Out:
# expandable_storage    0
# processor_family      0
# dtype: int64

# %% [markdown]
# ### Numerical features (missing values)

# %%
num_var_nan = [feature for feature in df.columns if df[feature].isna().sum() > 0 and df[feature].dtypes != 'O']

for feature in num_var_nan:
    print(f'{feature} : {round(df[feature].isna().mean(),4)}% missing values')
# Out:
# front_camera_mp : 0.0935% missing values
# rating : 0.0132% missing values
# reviews : 0.0132% missing values
# warranty_months : 0.2124% missing values

# %%
# Replacing nan numerical values with median
for feature in num_var_nan:
    med_val = df[feature].median()

    df[feature + 'nan'] = np.where(df[feature].isna(),1,0)#to know where the missing values
    df[feature].fillna(med_val,inplace = True)

df[num_var_nan].isna().sum()
# Out:
# front_camera_mp    0
# rating             0
# reviews            0
# warranty_months    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# brand                 0
# ram_gb                0
# storage_gb            0
# expandable_storage    0
# battery_type          0
# battery_mah           0
# rear_camera_mp        0
# front_camera_mp       0
# rear_camera_count     0
# rating                0
# reviews               0
# price                 0
# display_inch          0
# processor_family      0
# warranty_months       0
# front_camera_mpnan    0
# ratingnan             0
# reviewsnan            0
# warranty_monthsnan    0
# dtype: int64

# %%
df.head()
# Out:
#     brand    ram_gb  storage_gb      expandable_storage      battery_type  \
# 0   Redmi  4 GB RAM   64 GB ROM  Expandable Upto 512 GB  standard battery
# 1  Realme  4 GB RAM   64 GB ROM                 Missing  standard battery
# 2  Realme  4 GB RAM  128 GB ROM                 Missing  standard battery
# 3  Realme  4 GB RAM  128 GB ROM                 Missing  standard battery
# 4  Realme  3 GB RAM   32 GB ROM  Expandable Upto 256 GB  standard battery
#
#    battery_mah  rear_camera_mp  front_camera_mp  rear_camera_count  rating  \
# 0       5000.0              14              8.0                  2     4.4
# 1       5000.0              24              8.0                  4     4.5
# 2       5000.0              24              8.0                  4     4.5
# 3       5000.0              24              8.0                  4     4.5
# 4       4000.0              15              5.0                  2     4.4
#
#    reviews  price  display_inch processor_family  warranty_months  \
# ...

# %% [markdown]
# # Final Data Cleaning and EDA Summary

# %% [markdown]
# ### Data Cleaning & Preparation

# %% [raw]
# Inspected data types and corrected misclassified variables (e.g., RAM, storage, battery, camera specifications stored as text).
#
# Parsed and converted specification-related text fields into numerical features such as
# display_inch, battery_mah, rear_camera_mp, and front_camera_mp.
#
# Standardized high-cardinality categorical features by grouping semantically similar values
# (e.g., processor families, warranty duration formats).
#
# Identified and validated outliers in features like reviews and price,
# concluding they represent genuine popularity and premium products rather than data errors.

# %% [markdown]
# ### Missing Value Analysis

# %% [raw]
# Analyzed missing values not only by count but by their relationship with price.
#
# Found that missingness in features such as ratings, reviews, processor information,
# and warranty details was informative, often associated with higher-priced or newly launched devices.
#
# Retained informative missing values and avoided blind imputation.
#
# Applied median imputation only to features where missingness was random or caused by parsing limitations.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [raw]
# Performed univariate, bivariate, and multivariate analysis using histograms, boxplots, and scatter plots.
#
# Identified strong price drivers such as RAM, internal storage, processor family, camera resolution, and display size.
#
# Observed that battery capacity and display size are largely standardized across the market and
# act as baseline features rather than premium differentiators.
#
# Applied log transformations selectively for visualization to handle skewed distributions without altering original data.

# %% [markdown]
# ### Key Business Insights

# %% [raw]
# Smartphone pricing is driven by a combination of hardware tiering (RAM, storage, processor)
# and market adoption rather than single specifications.
#
# Popularity indicators (reviews, ratings) explain revenue dominance but do not directly imply higher per-unit pricing.
#
# Premium devices often exhibit sparse or missing user feedback due to lower sales volume or recent launches.
